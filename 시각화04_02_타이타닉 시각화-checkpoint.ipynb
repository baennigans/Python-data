# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
row_data = pd.read_csv('data/titanic.csv', sep='\t')
row_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
row_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
row_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
row_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
plt.rc('font', family='gulim')
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12,6))

ax[0].set_title('Survived')
row_data['Survived'].value_counts().plot.pie(autopct='%.1f%%', ax=ax[0])
ax[0].set_ylabel('')
row_data['Survived'].value_counts().plot.bar(ax=ax[1])
ax[1].set_ylabel('명')
ax[1].set_title('Survived')

sns.countplot(data=row_data, x='Survived', ax=ax[2])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
row_data['Survived'].value_counts().plot.pie(autopct='%.1f%%', explode=[0.1,0])
# Out:
# <Axes: ylabel='Survived'>

# %%
row_data['Survived'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
sns.countplot(data=row_data, x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=row_data, x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
row_data['Age'].hist(bins=7, grid=True)
# Out:
# <Axes: >

# %%
row_data.groupby('Pclass').mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23348\3846859950.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   row_data.groupby('Pclass').mean()
#         PassengerId  Survived        Age     SibSp     Parch      Fare
# Pclass
# 1         73.566667  0.400000  38.111111  0.533333  0.400000  79.50194
# 2         86.100000  0.466667  28.114828  0.400000  0.333333  23.65972
# 3         77.666667  0.291667  24.307143  0.708333  0.416667  13.44006

# %%
row_data.groupby('Age').mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23348\1793636351.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   row_data.groupby('Age').mean()
#        PassengerId  Survived    Pclass     SibSp     Parch        Fare
# Age
# 0.83     79.000000  1.000000  2.000000  0.000000  2.000000   29.000000
# 2.00     48.333333  0.000000  3.000000  3.666667  1.333333   27.158333
# 3.00     44.000000  1.000000  2.000000  1.000000  2.000000   41.579200
# 4.00     37.500000  0.500000  3.000000  2.000000  1.500000   22.300000
# 5.00     59.000000  1.000000  2.000000  1.000000  2.000000   27.750000
# 7.00     51.000000  0.000000  3.000000  4.000000  1.000000   39.687500
# 8.00     25.000000  0.000000  3.000000  3.000000  1.000000   21.075000
# 9.00    148.000000  0.000000  3.000000  2.000000  2.000000   34.375000
# 11.00    60.000000  0.000000  3.000000  5.000000  2.000000   46.900000
# 12.00   126.000000  1.000000  3.000000  1.000000  0.000000   11.241700
            include_lowest=True,
            labels=['baby', 'children', 'teenage', 'young', 
                    'adult', 'old'])

# %%
row_data['Age'].head(60)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# 20    35.0
# 21    34.0
# 22    15.0
# 23    28.0
# 24     8.0
# 25    38.0
# 26     NaN
# 27    19.0
# 28     NaN
# 29     NaN
# 30    40.0
# 31     NaN
# 32     NaN
# 33    66.0
# 34    28.0
# 35    42.0
# 36     NaN
# 37    21.0
# 38    18.0
# 39    14.0
# 40    40.0
# 41    27.0
# 42     NaN
# 43     3.0
# 44    19.0
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49    18.0
# 50     7.0
# 51    21.0
# 52    49.0
# 53    29.0
# 54    65.0
# 55     NaN
# 56    21.0
# 57    28.5
# 58     5.0
# 59    11.0
# Name: Age, dtype: float64

# %%
row_data['age_cut'].head(60)
# Out:
# 0        young
# 1        adult
# 2        young
# 3        adult
# 4        adult
# 5          NaN
# 6        adult
# 7         baby
# 8        young
# 9      teenage
# 10    children
# 11       adult
# 12       young
# 13       adult
# 14     teenage
# 15       adult
# 16        baby
# 17         NaN
# 18       adult
# 19         NaN
# 20       adult
# 21       adult
# 22     teenage
# 23       young
# 24     teenage
# 25       adult
# 26         NaN
# 27       young
# 28         NaN
# 29         NaN
# 30       adult
# 31         NaN
# 32         NaN
# 33         old
# 34       young
# 35       adult
# 36         NaN
# 37       young
# 38       young
# 39     teenage
# 40       adult
# 41       young
# 42         NaN
# 43        baby
# 44       young
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49       young
# 50    children
# 51       young
# 52       adult
# 53       young
# 54         old
# 55         NaN
# 56       young
# 57       young
# 58    children
# 59     teenage
# Name: age_cut, dtype: category
# Categories (6, object): ['baby' < 'children' < 'teenage' < 'young' < 'adult' < 'old']

# %%
row_data.groupby('age_cut').mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23348\338822790.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   row_data.groupby('age_cut').mean()
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# age_cut
# baby        53.600000  0.400000  2.600000   1.966000  2.400000  1.600000
# children    46.250000  0.500000  2.750000   5.000000  2.250000  1.500000
# teenage     62.111111  0.444444  2.888889  12.388889  1.555556  0.555556
# young       88.317460  0.333333  2.444444  22.912698  0.555556  0.333333
# adult       80.463415  0.292683  2.048780  41.182927  0.463415  0.414634
# old         75.750000  0.000000  1.750000  68.125000  0.000000  0.250000
#
#                Fare
# age_cut
# baby      30.410840
# children  28.009375
# teenage   20.582422
# young     32.334059
# adult     31.486278
# old       28.720850

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
sns.barplot(x='age_cut', y='Survived', data=row_data, ci=False)
plt.subplot(122)
sns.barplot(x='Sex', y='Survived', data=row_data, ci=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23348\1704291896.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='age_cut', y='Survived', data=row_data, ci=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_23348\1704291896.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=row_data, ci=False)
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.countplot(x='Sex', hue='Survived', data=row_data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>
